# %% [markdown]
# Pour **renverser une image** représentée sous forme de tableau NumPy en Python, tu peux utiliser les **opérations sur les indices NumPy**. Voici plusieurs méthodes selon le type de renversement souhaité :
#
# ### **1. Renverser l'image verticalement (haut ↔ bas)**
# Utilise `numpy.flipud()` ou `[::-1, :]` :
#
# ```python
# import numpy as np
# import matplotlib.pyplot as plt
#
# # Charger une image en tant que tableau numpy
# image = np.random.rand(100, 100, 3)  # Image RGB aléatoire (100x100)
#
# # Renverser verticalement
# image_flip_v = np.flipud(image)  # ou image[::-1, :]
#
# # Afficher l'image originale et renversée
# fig, ax = plt.subplots(1, 2)
# ax[0].imshow(image)
# ax[0].set_title("Originale")
# ax[1].imshow(image_flip_v)
# ax[1].set_title("Renversée Verticalement")
# plt.show()
# ```
#
# ---
#
# ### **2. Renverser l'image horizontalement (gauche ↔ droite)**
# Utilise `numpy.fliplr()` ou `[:, ::-1]` :
#
# ```python
# # Renverser horizontalement
# image_flip_h = np.fliplr(image)  # ou image[:, ::-1]
#
# # Afficher
# fig, ax = plt.subplots(1, 2)
# ax[0].imshow(image)
# ax[0].set_title("Originale")
# ax[1].imshow(image_flip_h)
# ax[1].set_title("Renversée Horizontalement")
# plt.show()
# ```
#
# ---
#
# ### **3. Renverser l'image en diagonale (Transpose + Flip)**
# Utilise `numpy.transpose()` + `numpy.flip()` :
#
# ```python
# # Renverser en diagonale (Transpose puis flip)
# image_flip_diag = np.flip(image.T, axis=1)  # ou image.transpose(1, 0, 2)[::-1, :]
#
# # Afficher
# fig, ax = plt.subplots(1, 2)
# ax[0].imshow(image)
# ax[0].set_title("Originale")
# ax[1].imshow(image_flip_diag)
# ax[1].set_title("Renversée en Diagonale")
# plt.show()
# ```
#
# ---
#
# ### **4. Rotation de 180° (Inversement total)**
# Utilise `numpy.flip()` deux fois ou `numpy.rot90(image, 2)` :
#
# ```python
# # Rotation de 180° (équivalent à flip horizontal + vertical)
# image_rot_180 = np.flip(image)  # ou np.rot90(image, 2)
#
# # Afficher
# fig, ax = plt.subplots(1, 2)
# ax[0].imshow(image)
# ax[0].set_title("Originale")
# ax[1].imshow(image_rot_180)
# ax[1].set_title("Rotée 180°")
# plt.show()
# ```
#
# ---
#
# ### **Résumé :**
# | Transformation | Méthode |
# |--------------|---------|
# | Renversement vertical | `np.flipud(image)` ou `image[::-1, :]` |
# | Renversement horizontal | `np.fliplr(image)` ou `image[:, ::-1]` |
# | Renversement diagonal | `image.T[::-1, :]` ou `np.flip(image.T, axis=1)` |
# | Rotation 180° | `np.flip(image)` ou `np.rot90(image, 2)` |
#
# Tu veux appliquer ça sur une image spécifique ? 😊

# %%
from scipy import misc

image=misc.face(gray=True)
plt.imshow(image,cmap=plt.cm.gray)
plt.show()
print('Voici la forme du tableau: ',image.shape)
# Out:
# C:\Users\genie\AppData\Local\Temp\ipykernel_1292\1121224196.py:3: DeprecationWarning: scipy.misc.face has been deprecated in SciPy v1.10.0; and will be completely removed in SciPy v1.12.0. Dataset methods have moved into the scipy.datasets module. Use scipy.datasets.face instead.
#   image=misc.face(gray=True)
# Voici la forme du tableau:  (768, 1024)

# %%
import numpy as np
import matplotlib.pyplot as plt



# Renverser verticalement
image_flip_v = np.flipud(image)  # ou image[::-1, :]

# Afficher l'image originale et renversée
fig, ax = plt.subplots(1, 2)
ax[0].imshow(image)
ax[0].set_title("Originale")
ax[1].imshow(image_flip_v)
ax[1].set_title("Renversée Verticalement")
plt.show()

# %%
### **2. Renverser l'image horizontalement (gauche ↔ droite)**
# Utilise `numpy.fliplr()` ou `[:, ::-1]` :


# Renverser horizontalement
image_flip_h = np.fliplr(image)  # ou image[:, ::-1]

# Afficher
fig, ax = plt.subplots(1, 2)
ax[0].imshow(image)
ax[0].set_title("Originale")
ax[1].imshow(image_flip_h)
ax[1].set_title("Renversée Horizontalement")
plt.show()

# %%
### **4. Rotation de 180° (Inversement total)**
# Utilise `numpy.flip()` deux fois ou `numpy.rot90(image, 2)` :

# Rotation de 180° (équivalent à flip horizontal + vertical)
image_rot_180 = np.flip(image)  # ou np.rot90(image, 2)

# Afficher
fig, ax = plt.subplots(1, 2)
ax[0].imshow(image)
ax[0].set_title("Originale")
ax[1].imshow(image_rot_180)
ax[1].set_title("Rotée 180°")
plt.show()
